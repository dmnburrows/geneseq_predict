# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path = '/home/dburrows/DATA/GENE_PREDICT/ISM'
path
# Out:
# '/home/dburrows/DATA/GENE_PREDICT/ISM'

# %%
! ls /home/dburrows/DATA/GENE_PREDICT/ISM
# Out:
# B1_neg_20bp_alphagenome.csv  B2_neg_20bp_alphagenome.csv  workspace.py
# B1_neu_20bp_alphagenome.csv  B2_neu_20bp_alphagenome.csv

# %%
curr = pd.read_csv(f'{path}/B1_neg_20bp_alphagenome.csv', index_col=0)
plt.hist(2**curr['logFC'])
plt.show()

# %%
(2**curr['logFC'] < 0.9).sum()
# Out:
# np.int64(19)

# %%
2/4
# Out:
# 0.5

# %%
logFC = np.log2((mut_mean + 1e-8) / (base_mean + 1e-8))

# %%
plt.hist(2**curr['logFC'])
plt.show()

# %%
curr = pd.read_csv(f'{path}/B1_neu_20bp_alphagenome.csv', index_col=0)
plt.hist(2**curr['logFC'])
plt.show()
(2**curr['logFC'] < 0.8).sum()
# Out:
# np.int64(52)

# %%
2**-0.39
# Out:
# 0.7631296044802796

# %%
curr
# Out:
#     reg mode                                          positions    refs  \
# 421  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 178  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 259  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 16   B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 664  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# ..   ..  ...                                                ...     ...
# 464  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 707  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 218  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 461  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 704  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
#
#        alts  n_mut  mut_mean  base_mean     delta     logFC
# 421  CTACTG      6  0.023370   0.027541 -0.004171 -0.236918
# 178  ATACTG      6  0.023405   0.027541 -0.004136 -0.234777
# 259  CCACTG      6  0.023467   0.027541 -0.004074 -0.230957
# 16   ACACTG      6  0.023472   0.027541 -0.004069 -0.230660
# 664  GTACTG      6  0.023717   0.027541 -0.003824 -0.215635
# ..      ...    ...       ...        ...       ...       ...
# 464  CTTAGT      6  0.030968   0.027541  0.003428  0.169225
# 707  GTTAGT      6  0.031400   0.027541  0.003859  0.189177
# 218  ATTAAT      6  0.032478   0.027541  0.004938  0.237912
# 461  CTTAAT      6  0.032997   0.027541  0.005456  0.260753
# 704  GTTAAT      6  0.033621   0.027541  0.006080  0.287777
#
# [729 rows x 10 columns]

# %%
curr['positions'][421]
# Out:
# '(np.int64(524283), np.int64(524289), np.int64(524290), np.int64(524291), np.int64(524293), np.int64(524294))'

# %%
curr = pd.read_csv(f'{path}/B2_neg_20bp_alphagenome.csv', index_col=0)
plt.hist(2**curr['logFC'])
plt.show()
(2**curr['logFC'] < 0.8).sum()
# Out:
# np.int64(15)

# %%
curr
# Out:
#       reg mode                                          positions       refs  \
# 3019   B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 7558   B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 832    B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 16141  B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 7555   B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# ...    ..  ...                                                ...        ...
# 17730  B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 11088  B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 17649  B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 9081   B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
# 9072   B2  neg  (np.int64(524281), np.int64(524282), np.int64(...  GCTTTCCAA
#
#             alts  n_mut  mut_mean  base_mean     delta     logFC
# 3019   AGCACATGG      9  0.021748   0.027541 -0.005793 -0.340702
# 7558   CACCAATTG      9  0.021807   0.027541 -0.005733 -0.336754
# 832    AACACATGG      9  0.021826   0.027541 -0.005715 -0.335542
# 16141  TGCACATGG      9  0.021844   0.027541 -0.005697 -0.334325
# 7555   CACCAATGG      9  0.021850   0.027541 -0.005691 -0.333942
# ...          ...    ...       ...        ...       ...       ...
# 17730  TTAAGTTCC      9  0.030167   0.027541  0.002626  0.131383
# 11088  CTAACTTCC      9  0.030336   0.027541  0.002795  0.139470
# 17649  TTAACTTCC      9  0.030495   0.027541  0.002954  0.146990
# 9081   CGACCAGCC      9  0.030711   0.027541  0.003170  0.157190
# 9072   CGACCAACC      9  0.030986   0.027541  0.003445  0.170022
#
# [19683 rows x 10 columns]

# %%
curr = pd.read_csv(f'{path}/B2_neu_20bp_alphagenome.csv', index_col=0)
plt.hist(2**curr['logFC'])
plt.show()
(2**curr['logFC'] < 0.9).sum()
# Out:
# np.int64(8)

# %%
curr
# Out:
#     reg mode                                          positions    refs  \
# 421  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 178  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 259  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 16   B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 664  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# ..   ..  ...                                                ...     ...
# 464  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 707  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 218  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 461  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
# 704  B2  neu  (np.int64(524283), np.int64(524289), np.int64(...  TAGGCA
#
#        alts  n_mut  mut_mean  base_mean     delta     logFC
# 421  CTACTG      6  0.023370   0.027541 -0.004171 -0.236918
# 178  ATACTG      6  0.023405   0.027541 -0.004136 -0.234777
# 259  CCACTG      6  0.023467   0.027541 -0.004074 -0.230957
# 16   ACACTG      6  0.023472   0.027541 -0.004069 -0.230660
# 664  GTACTG      6  0.023717   0.027541 -0.003824 -0.215635
# ..      ...    ...       ...        ...       ...       ...
# 464  CTTAGT      6  0.030968   0.027541  0.003428  0.169225
# 707  GTTAGT      6  0.031400   0.027541  0.003859  0.189177
# 218  ATTAAT      6  0.032478   0.027541  0.004938  0.237912
# 461  CTTAAT      6  0.032997   0.027541  0.005456  0.260753
# 704  GTTAAT      6  0.033621   0.027541  0.006080  0.287777
#
# [729 rows x 10 columns]
